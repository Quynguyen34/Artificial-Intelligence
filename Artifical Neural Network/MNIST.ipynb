# %%
from keras.datasets import mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
degit = train_images[99]
import matplotlib.pyplot as plt
plt.imshow(degit)
plt.show()
print('so nay la: ',train_labels[99])
# Out:
# so nay la:  1

# %%
degit = train_images[6000]
import matplotlib.pyplot as plt
plt.imshow(degit)
plt.show()
print('so nay la: ',train_labels[6000])
# Out:
# so nay la:  6

# %%
for i in range(10):
  plt.subplot(3,5,i+1)
  plt.tight_layout
  plt.imshow(train_images[i], cmap= 'gray', interpolation= 'none')
  plt.title("So nay la: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.tight_layout
  plt.imshow(train_images[i], cmap= 'gray', interpolation= 'none')
  plt.title("So nay la: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range(100):
  plt.subplot(10,10,i+1)
  plt.tight_layout
  plt.imshow(train_images[i], cmap= 'gray', interpolation= 'none')
  plt.title("So nay la: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()#ANN
model.add(Dense(512,activation = 'relu',input_shape =(28*28,)))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255

# %%
test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

# %%
#Onehot encoding convert
from keras.utils import to_categorical

train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

x=test_images
y=test_labels

# %%
#Data -> Model -> Compile -> Train -> experiense

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=20, batch_size=128)
test_loss, test_acc = model.evaluate(test_images,test_labels)
print('Do mat mat: ',test_loss)
print('Do chinh xac: ',test_acc)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2653 - accuracy: 0.9239
# Epoch 2/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1070 - accuracy: 0.9686
# Epoch 3/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0699 - accuracy: 0.9792
# Epoch 4/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0505 - accuracy: 0.9850
# Epoch 5/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0385 - accuracy: 0.9886
# Epoch 6/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0287 - accuracy: 0.9916
# Epoch 7/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0221 - accuracy: 0.9937
# Epoch 8/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0161 - accuracy: 0.9956
# Epoch 9/20
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0124 - accuracy: 0.9967
# Epoch 10/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0092 - accuracy: 0.9977
# Epoch 11/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0071 - accuracy: 0.9983
# Epoch 12/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 13/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 14/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0025 - accuracy: 0.9998
# Epoch 15/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 16/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0011 - accuracy: 0.9999
# Epoch 17/20
# 469/469 [==============================] - 4s 8ms/step - loss: 7.2125e-04 - accuracy: 0.9999
# Epoch 18/20
# 469/469 [==============================] - 4s 9ms/step - loss: 6.0159e-04 - accuracy: 1.0000
# Epoch 19/20
# 469/469 [==============================] - 4s 8ms/step - loss: 4.2381e-04 - accuracy: 1.0000
# Epoch 20/20
# 469/469 [==============================] - 3s 7ms/step - loss: 3.5964e-04 - accuracy: 1.0000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0644 - accuracy: 0.9836
# Do mat mat:  0.06435264647006989
# Do chinh xac:  0.9836000204086304

# %%
model.save('MINIST.h5')

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from keras.utils import load_img
from keras.utils import img_to_array
from pylab import *
import numpy as np
from PIL import Image
from keras.models import load_model
from IPython.display import display

#Load model
model = load_model('MINIST.h5')

#Open image uploaded 
img = Image.open('7.jpg')

#Display image uploaded
display(img)

#Convert to gray Image
img = img.convert('L')

#Resize to 28x28 image
img = img.resize((28,28))

#Show image
plt.imshow(img, cmap= 'gray', interpolation= 'none')
plt.show()

#Convert image to numpy array
img = np.array(img)

#Reshape array to Vector(1, 28*28)
img = img.reshape(1,28*28)

#Rescale pixel value from (0, 255) to (0, 1)
img = img.astype('float32') / 255

#Prediction and displaying the result on the screen
predictions = model.predict(img)
digit = np.argmax(predictions)
print('Predicted digit:', digit)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=290x290 at 0x7F6FFF044100>
# 1/1 [==============================] - 0s 93ms/step
# Predicted digit: 5
