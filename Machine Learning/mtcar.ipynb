# %%
#BAC 1
import pandas as pd
url ='/content/mtcars.csv'
data = pd.read_csv(url)
data.head()

import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()


correlation = data.corr()
print(correlation)

sns.pairplot(data)

sns.heatmap(correlation, annot = True)

data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')

from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print('Value Intercept: ',model.intercept_)
print('Value tri Coeffient: ',model.coef_)

model.score(X=pd.DataFrame(data['wt']),y=data['mpg'])

#data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')
y_pred = model.predict(X=pd.DataFrame(data['wt']))
plt.plot(data['wt'],y_pred,color = 'blue')
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Value Intercept:  37.28512616734204
# Value tri Coeffient:  [-5.34447157]

# %%
#BAC 2
import numpy as np
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('He so Intercept: ',model.intercept_)
print('He so Coeffient: ',model.coef_)
print('Do chinh xac cua mo hinh: ',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X_range)
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept:  49.93081094945181
# He so Coeffient:  [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh:  0.8190613581384094
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#BAC 3
import numpy as np
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3]).T
model.fit(X,y=data['mpg'])
print('He so Intercept: ',model.intercept_)
print('He so Coeffient: ',model.coef_)
print('Do chinh xac cua mo hinh: ',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2,range**3]).T
y_pred=model.predict(X_range)
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept:  48.40369622795221
# He so Coeffient:  [-11.82597602   0.68937919   0.04593618]
# Do chinh xac cua mo hinh:  0.8191284628478992
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#BAC 4
import numpy as np
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4]).T
model.fit(X,y=data['mpg'])
print('He so Intercept: ',model.intercept_)
print('He so Coeffient: ',model.coef_)
print('Do chinh xac cua mo hinh: ',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2,range**3,range**4]).T
y_pred=model.predict(X_range)
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept:  14.455833054796258
# He so Coeffient:  [ 36.61945631 -23.70175729   5.20042113  -0.38627878]
# Do chinh xac cua mo hinh:  0.8219709873435187
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#BAC 5
import numpy as np
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('He so Intercept: ',model.intercept_)
print('He so Coeffient: ',model.coef_)
print('Do chinh xac cua mo hinh: ',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred=model.predict(X_range)
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept:  -87.71816314301019
# He so Coeffient:  [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# Do chinh xac cua mo hinh:  0.8251088272653132
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#BAC 20
import numpy as np
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5
                  ,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10
                  ,data['wt']**11,data['wt']**12,data['wt']**13,data['wt']**14
                  ,data['wt']**15,data['wt']**16,data['wt']**17,data['wt']**18
                  ,data['wt']**19,data['wt']**20]).T
model.fit(X,y=data['mpg'])
print('He so Intercept: ',model.intercept_)
print('He so Coeffient: ',model.coef_)
print('Do chinh xac cua mo hinh: ',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9
                      ,range**10,range**11,range**12,range**13,range**14,range**15,range**16,range**17
                      ,range**18,range**19,range**20]).T
y_pred=model.predict(X_range)
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept:  31.60116283297539
# He so Coeffient:  [-1.97751688e-01 -4.61457294e-01 -6.73776309e-01 -7.66008671e-01
#  -5.84901227e-01 -7.82144223e-02  5.74178632e-01  9.01634190e-01
#   4.29779708e-01 -6.08364736e-01 -9.01919647e-01  3.83801294e-01
#   9.62236538e-01 -1.10739600e+00  5.56319926e-01 -1.62874849e-01
#   2.96775386e-02 -3.33198739e-03  2.11904686e-04 -5.85903111e-06]
# Do chinh xac cua mo hinh:  0.879188626967333
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp']], y=data['mpg'])
print('He so Coeffient: ',model.coef_)
print('He so Intercept: ',model.intercept_)
print('Do chinh xac cua mo hinh: ',model.score(X=data.loc[:,['wt','hp']], y=data['mpg']))
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,200))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Coeffient:  [-3.87783074 -0.03177295]
# He so Intercept:  37.227270116447215
# Do chinh xac cua mo hinh:  0.8267854518827914
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp','disp']], y=data['mpg'])
print('He so Coeffient: ',model.coef_)
print('He so Intercept: ',model.intercept_)
print('Do chinh xac cua mo hinh: ',model.score(X=data.loc[:,['wt','hp','disp']], y=data['mpg']))
data.plot(kind = 'scatter',x ='wt', y='mpg',figsize=(9,9),color='black',xlim=(0,200))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Coeffient:  [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
# He so Intercept:  37.10550526903184
# Do chinh xac cua mo hinh:  0.8268361424946447
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
